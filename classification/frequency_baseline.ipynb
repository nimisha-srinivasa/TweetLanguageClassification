# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from collections import Counter

# %%
# loading the pre-processed data
processed_data = pd.read_json("processed_data.json")

# %%
# randomizing the data
data = processed_data.iloc[np.random.permutation(len(processed_data))]
print(data.shape)
# Out:
# (71410, 3)

# %%
#spliting the data into 80:20 training testing ratio

msk = np.random.rand(len(data)) < 0.8
train = data[msk]
test = data[~msk]
print(train.shape)
print(test.shape)
# Out:
# (57232, 3)
# (14178, 3)

# %%
train.columns
# Out:
# Index([u'content', u'id', u'label'], dtype='object')

# %%
label_counts =train['label'].value_counts()
len(label_counts)
# Out:
# 58

# %%
label_counts_index = label_counts.index
label_counts_index
# Out:
# Index([u'en', u'ja', u'es', u'pt', u'id', u'und', u'ar', u'ru', u'fr', u'tr',
#        u'ko', u'th', u'tl', u'it', u'de', u'nl', u'ms', u'pl', u'sv', u'el',
#        u'he', u'sr', u'zh-CN', u'fi', u'uk', u'ca', u'lv', u'fa', u'ar_LATN',
#        u'hi', u'vi', u'jv', u'ro', u'ur_LATN', u'zh-TW', u'da', u'hi-Latn',
#        u'no', u'hu', u'ur', u'su', u'sw', u'ta', u'cs', u'bs', u'ne', u'sq',
#        u'hr', u'ht', u'az', u'gl', u'km', u'mr', u'mn', u'xh', u'bg',
#        u'ja_LATN', u'ko_LATN'],
#       dtype='object')

# %%
len(label_counts_index)
# Out:
# 58

# %%
pp = {}
for i in label_counts_index:
    pp[i] = train.loc[train['label'] == i]
    
print(len(pp)) 
pp['en'].shape
# Out:
# 58
# (20379, 3)

# %%
def do_vectorize(data,min_df = 1,max_df = 1.0,binary =True,ngram_range = (1,1)):
    
    vec = CountVectorizer(max_df=max_df, min_df=min_df,binary=binary, ngram_range=ngram_range)
    X = vec.fit_transform(data)
    return (X, vec)

# %%
cc = {}
most_frequent = {}
for i in pp.keys():
    X,vec = do_vectorize(pp[i]['content'])
    cc[i] = zip(vec.get_feature_names(),np.asarray(X.sum(axis=0)).ravel())
    most_frequent[i] = sorted(cc[i], key=lambda tup: tup[1], reverse=True)[:100]

# %%
len(most_frequent)
# Out:
# 58

# %%
most_frequent['en']
# Out:
# [(u'the', 3797),
#  (u'to', 3470),
#  (u'you', 3088),
#  (u'and', 2339),
#  (u'me', 2048),
#  (u'my', 2019),
#  (u'in', 1917),
#  (u'for', 1850),
#  (u'is', 1823),
#  (u'of', 1711),
#  (u'it', 1432),
#  (u'on', 1409),
#  (u'so', 1273),
#  (u'im', 1200),
#  (u'this', 1171),
#  (u'that', 1130),
#  (u'with', 1059),
#  (u'be', 1027),
#  (u'love', 955),
#  (u'just', 910),
#  (u'your', 909),
#  (u'at', 908),
#  (u'have', 842),
#  (u'are', 764),
#  (u'like', 762),
#  (u'not', 748),
#  (u'but', 747),
#  (u'follow', 746),
#  (u'its', 717),
#  (u'one', 695),
#  (u'if', 671),
#  (u'up', 670),
#  (u'dont', 667),
#  (u'out', 648),
#  (u'do', 628),
#  (u'from', 614),
#  (u'can', 612),
#  (u'please', 600),
#  (u'what', 596),
#  (u'all', 582),
#  (u'get', 573),
#  (u'new', 573),
#  (u'by', 566),
#  (u'no', 564),
#  (u'was', 560),
#  (u'we', 527),
#  (u'now', 510),
#  (u'amp', 508),
#  (u'go', 506),
#  (u'when', 498),
#  (u'today', 489),
#  (u'know', 467),
#  (u'more', 466),
#  (u'lol', 438),
#  (u'how', 428),
#  (u'good', 426),
#  (u'via', 424),
#  (u'day', 412),
#  (u'much', 412),
#  (u'will', 408),
#  (u'about', 406),
#  (u'time', 398),
#  (u'people', 395),
#  (u'see', 384),
#  (u'too', 376),
#  (u'would', 369),
#  (u'make', 368),
#  (u'or', 350),
#  (u'they', 349),
#  (u'want', 349),
#  (u'why', 349),
#  (u'as', 344),
#  (u'need', 343),
#  (u'happy', 338),
#  (u'got', 337),
#  (u'cant', 333),
#  (u'who', 332),
#  (u'back', 313),
#  (u'he', 303),
#  (u'an', 300),
#  (u'really', 277),
#  (u'youre', 275),
#  (u'think', 272),
#  (u'her', 267),
#  (u'there', 265),
#  (u'ive', 262),
#  (u'thats', 259),
#  (u'life', 255),
#  (u'some', 255),
#  (u'going', 245),
#  (u'been', 239),
#  (u'she', 238),
#  (u'shit', 238),
#  (u'am', 237),
#  (u'has', 234),
#  (u'them', 232),
#  (u'come', 228),
#  (u'best', 227),
#  (u'even', 226),
#  (u'still', 226)]

# %%
def fun(string):
    string_label = []
    for word in string.split():
        #print word

        for sym in most_frequent:
            #print sym

            for i in most_frequent[sym]:

                if i[0] == word:
                    string_label.append(sym)
    if len(string_label) == 0:
        string_label.append('en')
                
    
    c = Counter(string_label)
    #print c
    v=list(c.values())
    k=list(c.keys())
    return k[v.index(max(v))]

# %%
predicted_labels = []
for i in test['content']:
    #print i
    predicted_labels.append(fun(i))

# %%
Counter(string_label)
# Out:
# Counter({u'en': 4, u'mr': 1, u'nl': 1})

# %%
predicted_labels
# Out:
# ['en',
#  u'en',
#  u'es',
#  u'en',
#  u'ar',
#  u'fr',
#  u'en',
#  u'en',
#  'en',
#  u'lv',
#  u'es',
#  u'und',
#  'en',
#  'en',
#  u'pt',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'su',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'und',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'fr',
#  'en',
#  u'it',
#  u'fr',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'pt',
#  u'en',
#  u'fr',
#  u'en',
#  'en',
#  u'ca',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'fr',
#  u'en',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'fr',
#  u'el',
#  u'ar',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'fr',
#  u'ar',
#  u'es',
#  u'en',
#  u'tl',
#  u'es',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'es',
#  u'en',
#  u'en',
#  u'pt',
#  'en',
#  'en',
#  u'en',
#  u'tl',
#  'en',
#  u'es',
#  u'fr',
#  u'en',
#  'en',
#  u'en',
#  u'fr',
#  u'ur_LATN',
#  u'en',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'fr',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  u'und',
#  'en',
#  u'en',
#  'en',
#  u'ar',
#  u'en',
#  'en',
#  u'en',
#  u'el',
#  u'en',
#  'en',
#  'en',
#  u'ar',
#  'en',
#  u'fr',
#  u'id',
#  'en',
#  u'ur_LATN',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'ms',
#  'en',
#  u'nl',
#  'en',
#  u'fr',
#  u'en',
#  'en',
#  u'en',
#  u'ru',
#  'en',
#  'en',
#  u'en',
#  u'es',
#  'en',
#  u'nl',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'es',
#  'en',
#  'en',
#  u'id',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'fr',
#  u'und',
#  u'en',
#  u'en',
#  u'vi',
#  u'en',
#  u'und',
#  'en',
#  'en',
#  'en',
#  u'und',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  u'pt',
#  u'fr',
#  u'und',
#  'en',
#  u'en',
#  'en',
#  u'tr',
#  'en',
#  u'es',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'tl',
#  u'en',
#  'en',
#  u'en',
#  u'pt',
#  u'jv',
#  u'ca',
#  'en',
#  u'ar',
#  'en',
#  'en',
#  u'pt',
#  u'ru',
#  'en',
#  'en',
#  u'pt',
#  'en',
#  u'pt',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  u'ar',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  u'fr',
#  u'en',
#  u'en',
#  u'en',
#  u'pt',
#  u'ms',
#  'en',
#  u'ca',
#  'en',
#  u'ar',
#  'en',
#  'en',
#  u'en',
#  u'ar',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'pt',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  u'su',
#  'en',
#  u'en',
#  u'ar',
#  'en',
#  'en',
#  'en',
#  u'sv',
#  'en',
#  u'fr',
#  'en',
#  'en',
#  'en',
#  u'ms',
#  u'en',
#  u'en',
#  u'ca',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'und',
#  u'en',
#  u'es',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'ru',
#  u'en',
#  u'tl',
#  u'ru',
#  'en',
#  'en',
#  'en',
#  u'ur_LATN',
#  'en',
#  'en',
#  u'ar',
#  u'fr',
#  'en',
#  u'en',
#  u'su',
#  u'ar',
#  'en',
#  u'ca',
#  u'tl',
#  'en',
#  'en',
#  u'ar',
#  u'en',
#  u'lv',
#  u'en',
#  'en',
#  u'id',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'pt',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  u'en',
#  u'ar',
#  u'en',
#  u'id',
#  'en',
#  u'en',
#  u'id',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  u'ru',
#  u'ar',
#  u'ar',
#  'en',
#  u'en',
#  'en',
#  u'ru',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'lv',
#  u'en',
#  'en',
#  u'id',
#  'en',
#  u'es',
#  'en',
#  u'fi',
#  'en',
#  u'pt',
#  u'ar',
#  u'fr',
#  u'pt',
#  u'jv',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'jv',
#  u'es',
#  u'es',
#  u'ru',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  u'es',
#  u'tl',
#  u'es',
#  'en',
#  u'es',
#  u'fr',
#  u'en',
#  'en',
#  u'pt',
#  'en',
#  'en',
#  u'it',
#  u'es',
#  u'en',
#  u'fr',
#  u'en',
#  'en',
#  u'en',
#  u'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'tl',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'fa',
#  u'en',
#  u'tr',
#  u'fr',
#  u'en',
#  u'es',
#  u'en',
#  u'es',
#  u'en',
#  u'ru',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'es',
#  u'und',
#  u'en',
#  u'en',
#  u'tr',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  u'nl',
#  'en',
#  u'id',
#  u'de',
#  u'ur',
#  u'en',
#  u'en',
#  u'pt',
#  'en',
#  'en',
#  u'es',
#  u'pt',
#  u'en',
#  u'fr',
#  u'ja',
#  u'pt',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'pt',
#  'en',
#  u'en',
#  u'en',
#  u'id',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'id',
#  u'en',
#  u'pt',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'ca',
#  u'id',
#  u'nl',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  u'es',
#  u'en',
#  u'id',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  u'en',
#  u'pt',
#  u'ja',
#  'en',
#  'en',
#  u'ru',
#  u'es',
#  u'pt',
#  'en',
#  u'id',
#  u'en',
#  'en',
#  'en',
#  u'tl',
#  'en',
#  'en',
#  u'tr',
#  'en',
#  u'id',
#  'en',
#  u'id',
#  'en',
#  u'pt',
#  u'en',
#  'en',
#  'en',
#  u'fi',
#  u'en',
#  'en',
#  u'ms',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'pt',
#  'en',
#  u'ar',
#  'en',
#  'en',
#  u'en',
#  u'tl',
#  u'tl',
#  u'id',
#  u'en',
#  u'fr',
#  u'en',
#  u'fr',
#  u'en',
#  'en',
#  u'de',
#  'en',
#  u'pt',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'es',
#  'en',
#  'en',
#  u'ru',
#  'en',
#  u'en',
#  u'pt',
#  u'en',
#  'en',
#  'en',
#  u'fr',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  u'id',
#  u'en',
#  u'es',
#  u'id',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'pt',
#  u'en',
#  u'en',
#  u'pt',
#  u'fr',
#  'en',
#  u'fr',
#  'en',
#  u'und',
#  'en',
#  u'ar',
#  u'en',
#  u'en',
#  u'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'ar',
#  'en',
#  'en',
#  'en',
#  u'id',
#  u'en',
#  u'id',
#  u'id',
#  u'und',
#  'en',
#  'en',
#  u'pt',
#  u'en',
#  u'es',
#  'en',
#  'en',
#  u'nl',
#  u'en',
#  u'en',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'ca',
#  u'en',
#  u'es',
#  'en',
#  u'sv',
#  'en',
#  'en',
#  u'und',
#  u'lv',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'tr',
#  u'fr',
#  u'und',
#  u'en',
#  'en',
#  u'hi-Latn',
#  u'fr',
#  'en',
#  'en',
#  'en',
#  u'su',
#  'en',
#  'en',
#  u'en',
#  u'pt',
#  'en',
#  u'und',
#  u'en',
#  u'en',
#  u'nl',
#  'en',
#  'en',
#  u'fr',
#  u'es',
#  u'pt',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'pt',
#  u'nl',
#  'en',
#  u'id',
#  u'ar',
#  u'en',
#  u'tr',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'ar',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'nl',
#  u'id',
#  'en',
#  'en',
#  u'und',
#  u'en',
#  'en',
#  'en',
#  u'tr',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  u'es',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'und',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'es',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'id',
#  u'en',
#  u'en',
#  'en',
#  u'en',
#  'en',
#  u'en',
#  u'en',
#  u'tr',
#  u'ar',
#  'en',
#  'en',
#  'en',
#  u'fr',
#  u'es',
#  u'en',
#  u'ar',
#  'en',
#  u'en',
#  u'id',
#  'en',
#  'en',
#  u'fr',
#  u'en',
#  u'ar',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'es',
#  'en',
#  u'en',
#  u'und',
#  'en',
#  u'en',
#  u'fr',
#  u'en',
#  'en',
#  u'nl',
#  'en',
#  u'es',
#  u'fr',
#  'en',
#  u'en',
#  u'en',
#  u'id',
#  'en',
#  u'en',
#  u'pt',
#  u'en',
#  'en',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  u'es',
#  u'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'it',
#  u'id',
#  'en',
#  u'es',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  u'pt',
#  'en',
#  u'en',
#  u'jv',
#  'en',
#  u'fr',
#  'en',
#  'en',
#  u'fr',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  u'ar',
#  u'und',
#  u'en',
#  u'ja',
#  u'fr',
#  'en',
#  u'en',
#  u'en',
#  u'ja',
#  u'en',
#  u'es',
#  'en',
#  u'id',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'es',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'id',
#  u'el',
#  u'en',
#  u'en',
#  u'en',
#  u'fr',
#  'en',
#  u'en',
#  'en',
#  'en',
#  u'ja',
#  u'tr',
#  u'ar',
#  'en',
#  u'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'id',
#  u'en',
#  u'pt',
#  u'jv',
#  u'en',
#  u'en',
#  u'pt',
#  'en',
#  u'en',
#  u'en',
#  u'lv',
#  u'es',
#  'en',
#  u'en',
#  u'en',
#  u'ar',
#  u'en',
#  u'en',
#  u'id',
#  u'pt',
#  'en',
#  u'en',
#  u'fr',
#  u'en',
#  u'en',
#  'en',
#  u'sv',
#  'en',
#  'en',
#  u'vi',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  'en',
#  u'id',
#  u'ar',
#  'en',
#  u'en',
#  u'en',
#  u'en',
#  u'en',
#  u'es',
#  u'el',
#  'en',
#  'en',
#  u'en',
#  u'ja',
#  'en',
#  'en',
#  u'en',
#  u'en',
#  u'ar',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  'en',
#  'en',
#  'en',
#  u'en',
#  u'ru',
#  u'el',
#  u'en',
#  u'fr',
#  u'es',
#  u'en',
#  'en',
#  'en',
#  u'tl',
#  u'en',
#  u'it',
#  ...]

# %%
from sklearn.metrics import accuracy_score
y_pred = test['label']
y_true = predicted_labels
accuracy_score(y_true, y_pred)
# Out:
# 0.54989744677841434
